# %%
import pandas as pd

# %%
# individually loading each file and showing the shape
# I realized that a large tail end of this data is completely empty and double checked the .csv source 
# Was this intentional?

file1 = pd.read_csv('files_for_lab/csv_files/file1.csv')
display(file1.head())
display(file1.tail())
file1.shape
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2 = pd.read_csv('files_for_lab/csv_files/file2.csv')
display(file2.head())
display(file2.tail())
file2.shape
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3 = pd.read_csv('files_for_lab/csv_files/file3.csv')
display(file3.head())
display(file3.tail())
file3.shape
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
# printing column headers to compare and contrast

print(file1.columns)
print(file2.columns) 
print(file3.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
# I tried but failed to define a function that would help rename and reorder headers for all files. 
# I ended up with 12 instead of 11 rows, as State and ST weren't merged as I had hoped. 
# Left the function here below to show my method, so you may help me figure out where I went wrong

def ProperHeaders(filename):
    cols = []
    for column in filename.columns:
        cols.append(column.title())
    cols
    filename.columns = cols
    filename = filename.rename(columns={'St':'State',
                                        'Customer Lifetime Value':'Customer_Lifetime_Value', 
                                        'Monthly Premium Auto':'Monthly_Premium_Auto',
                                        'Number Of Open Complaints':'Number_Of_Open_Complaints',
                                        'Total Claim Amount':'Total_Claim_Amount',
                                        'Policy Type':'Policy_Type',
                                        'Vehicle Class':'Vehicle_Class'})
    filename = filename[['Customer', 
                         'State',
                         'Gender', 
                         'Education', 
                         'Customer_Lifetime_Value', 
                         'Income', 
                         'Monthly_Premium_Auto', 
                         'Number_Of_Open_Complaints', 
                         'Policy_Type', 
                         'Vehicle_Class', 
                         'Total_Claim_Amount']]
    
    print(filename.columns)

# %%
# Instead, I changed headers file by file

cols = []
for column in file1.columns:
    cols.append(column.title())
cols
file1.columns = cols
file1 = file1.rename(columns={'St':'State',
                                    'Customer Lifetime Value':'Customer_Lifetime_Value', 
                                    'Monthly Premium Auto':'Monthly_Premium_Auto',
                                    'Number Of Open Complaints':'Number_Of_Open_Complaints',
                                    'Total Claim Amount':'Total_Claim_Amount',
                                    'Policy Type':'Policy_Type',
                                    'Vehicle Class':'Vehicle_Class'})
file1 = file1[['Customer', 
                     'State',
                     'Gender', 
                     'Education', 
                     'Customer_Lifetime_Value', 
                     'Income', 
                     'Monthly_Premium_Auto', 
                     'Number_Of_Open_Complaints', 
                     'Policy_Type', 
                     'Vehicle_Class', 
                     'Total_Claim_Amount']]
file1.head()
file1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
cols = []
for column in file2.columns:
    cols.append(column.title())
cols
file2.columns = cols
file2 = file2.rename(columns={'St':'State',
                                    'Customer Lifetime Value':'Customer_Lifetime_Value', 
                                    'Monthly Premium Auto':'Monthly_Premium_Auto',
                                    'Number Of Open Complaints':'Number_Of_Open_Complaints',
                                    'Total Claim Amount':'Total_Claim_Amount',
                                    'Policy Type':'Policy_Type',
                                    'Vehicle Class':'Vehicle_Class'})
file2 = file2[['Customer', 
                     'State',
                     'Gender', 
                     'Education', 
                     'Customer_Lifetime_Value', 
                     'Income', 
                     'Monthly_Premium_Auto', 
                     'Number_Of_Open_Complaints', 
                     'Policy_Type', 
                     'Vehicle_Class', 
                     'Total_Claim_Amount']]
file2.head()
file2
# Out:
#     Customer       State Gender Education Customer_Lifetime_Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_Premium_Auto Number_Of_Open_Complaints     Policy_Type  \
# ...

# %%
cols = []
for column in file3.columns:
    cols.append(column.title())
cols
file3.columns = cols
file3 = file3.rename(columns={'St':'State',
                                    'Customer Lifetime Value':'Customer_Lifetime_Value', 
                                    'Monthly Premium Auto':'Monthly_Premium_Auto',
                                    'Number Of Open Complaints':'Number_Of_Open_Complaints',
                                    'Total Claim Amount':'Total_Claim_Amount',
                                    'Policy Type':'Policy_Type',
                                    'Vehicle Class':'Vehicle_Class'})
file3 = file3[['Customer', 
                     'State',
                     'Gender', 
                     'Education', 
                     'Customer_Lifetime_Value', 
                     'Income', 
                     'Monthly_Premium_Auto', 
                     'Number_Of_Open_Complaints', 
                     'Policy_Type', 
                     'Vehicle_Class', 
                     'Total_Claim_Amount']]
file3.head()
file3
# Out:
#      Customer       State Gender             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer_Lifetime_Value  Income  Monthly_Premium_Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
dataset = pd.concat([file1, file2, file3], axis=0)
dataset.shape
dataset
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
dataset.dtypes
# Out:
# Customer                      object
# State                         object
# Gender                        object
# Education                     object
# Customer_Lifetime_Value       object
# Income                       float64
# Monthly_Premium_Auto         float64
# Number_Of_Open_Complaints     object
# Policy_Type                   object
# Vehicle_Class                 object
# Total_Claim_Amount           float64
# dtype: object

# %%
dataset._get_numeric_data()
# Out:
#        Income  Monthly_Premium_Auto  Total_Claim_Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %% [markdown]
# ### after checking through the data, Income, Monthly_Premium_Auto and Total_Claim_Amount are definetely numerical. The rest are categorical - except Customer_Lifetime_Value which seems to be numerical, but due to false data is labelled as 'object' - I am unsure if the same applies to Number_Of_Open_Complaints which in one file is a simple number and in the other two seems to have a format X/X/XX

# %%
# deleting education and the number of open complaints but first saving my concatenated dataset

dataset.to_csv('files_for_lab/csv_files/dataset.csv')

# %%
dataset_save = dataset

# %%
dataset = dataset.drop(['Education','Number_Of_Open_Complaints'], axis=1)
dataset.head()
# Out:
#   Customer       State Gender Customer_Lifetime_Value   Income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %%
# in the codecells below I cut down the cells with null values.

# %%
dataset.isna().sum()
# Out:
# Customer                   2937
# State                      2937
# Gender                     3059
# Customer_Lifetime_Value    2944
# Income                     2937
# Monthly_Premium_Auto       2937
# Policy_Type                2937
# Vehicle_Class              2937
# Total_Claim_Amount         2937
# dtype: int64

# %%
file1.isna().sum()
# Out:
# Customer                     2937
# State                        2937
# Gender                       3054
# Education                    2937
# Customer_Lifetime_Value      2940
# Income                       2937
# Monthly_Premium_Auto         2937
# Number_Of_Open_Complaints    2937
# Policy_Type                  2937
# Vehicle_Class                2937
# Total_Claim_Amount           2937
# dtype: int64

# %%
file2.isna().sum()
# Out:
# Customer                     0
# State                        0
# Gender                       5
# Education                    0
# Customer_Lifetime_Value      4
# Income                       0
# Monthly_Premium_Auto         0
# Number_Of_Open_Complaints    0
# Policy_Type                  0
# Vehicle_Class                0
# Total_Claim_Amount           0
# dtype: int64

# %%
file3.isna().sum()
# Out:
# Customer                     0
# State                        0
# Gender                       0
# Education                    0
# Customer_Lifetime_Value      0
# Income                       0
# Monthly_Premium_Auto         0
# Number_Of_Open_Complaints    0
# Policy_Type                  0
# Vehicle_Class                0
# Total_Claim_Amount           0
# dtype: int64

# %%
dataset = dataset[dataset['Customer'].isna()==False]

# %%
dataset.isna().sum()
# Out:
# Customer                     0
# State                        0
# Gender                     122
# Customer_Lifetime_Value      7
# Income                       0
# Monthly_Premium_Auto         0
# Policy_Type                  0
# Vehicle_Class                0
# Total_Claim_Amount           0
# dtype: int64

# %%
round(dataset.isna().sum()/len(dataset),4)*100  
nulls_df = pd.DataFrame(round(dataset.isna().sum()/len(dataset),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                header_name  percent_nulls
# 0                 Customer           0.00
# 1                    State           0.00
# 2                   Gender           1.34
# 3  Customer_Lifetime_Value           0.08
# 4                   Income           0.00
# 5     Monthly_Premium_Auto           0.00
# 6              Policy_Type           0.00
# 7            Vehicle_Class           0.00
# 8       Total_Claim_Amount           0.00

# %%
# since gender and customer lifetime value have very low number of nulls, I decided to remove these rows

# %%
dataset = dataset[dataset['Gender'].isna()==False]

# %%
dataset = dataset[dataset['Customer_Lifetime_Value'].isna()==False]

# %%
dataset.isna().sum()
# Out:
# Customer                   0
# State                      0
# Gender                     0
# Customer_Lifetime_Value    0
# Income                     0
# Monthly_Premium_Auto       0
# Policy_Type                0
# Vehicle_Class              0
# Total_Claim_Amount         0
# dtype: int64

# %%
# removing percentages below

# %%
dataset['Customer_Lifetime_Value'] = dataset['Customer_Lifetime_Value'].str.rstrip('%').astype('float') / 100.0

# %%
dataset.head()
# Out:
#   Customer       State Gender  Customer_Lifetime_Value   Income  \
# 1  QZ44356     Arizona      F                6979.5359      0.0
# 2  AI49188      Nevada      F               12887.4317  48767.0
# 3  WW63253  California      M                7645.8618      0.0
# 4  GA49547  Washington      M                5363.0765  36357.0
# 5  OC83172      Oregon      F                8256.2978  62902.0
#
#    Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
# 5                  69.0   Personal Auto   Two-Door Car          159.383042

# %%
dataset.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer_Lifetime_Value    float64
# Income                     float64
# Monthly_Premium_Auto       float64
# Policy_Type                 object
# Vehicle_Class               object
# Total_Claim_Amount         float64
# dtype: object

# %%
# Removing duplicates

print(dataset.shape)
dataset2 = dataset.copy()

# dataset2 = dataset2.drop_duplicates()

# Instead of using the above I am basing my duplicate removal on the customer value, 
# which should be a unique identifier

dataset2 = dataset2.drop_duplicates(subset=['Customer'],keep='last')

print(dataset2.shape)
# Out:
# (9010, 9)
# (8933, 9)

# %%
dataset2.head()
# Out:
#   Customer       State Gender  Customer_Lifetime_Value   Income  \
# 1  QZ44356     Arizona      F                6979.5359      0.0
# 2  AI49188      Nevada      F               12887.4317  48767.0
# 3  WW63253  California      M                7645.8618      0.0
# 5  OC83172      Oregon      F                8256.2978  62902.0
# 6  XZ87318      Oregon      F                5380.8986  55350.0
#
#    Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 5                  69.0   Personal Auto   Two-Door Car          159.383042
# 6                  67.0  Corporate Auto  Four-Door Car          321.600000

# %%
dataset2 = dataset2[dataset2.Income != 0]

# %%
dataset2.head()
# Out:
#   Customer   State Gender  Customer_Lifetime_Value   Income  \
# 2  AI49188  Nevada      F               12887.4317  48767.0
# 5  OC83172  Oregon      F                8256.2978  62902.0
# 6  XZ87318  Oregon      F                5380.8986  55350.0
# 8  DY87989  Oregon      M               24127.5040  14072.0
# 9  BQ94931  Oregon      F                7388.1781  28812.0
#
#    Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 5                  69.0   Personal Auto   Two-Door Car          159.383042
# 6                  67.0  Corporate Auto  Four-Door Car          321.600000
# 8                  71.0  Corporate Auto  Four-Door Car          511.200000
# 9                  93.0    Special Auto  Four-Door Car          425.527834
